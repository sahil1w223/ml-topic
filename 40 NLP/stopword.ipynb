# %%
paragraph = '''
   Good morning to everyone present here. Today, I am going to speak about Dr. A.P.J. Abdul Kalam, one of the most respected personalities in India. Dr. A.P.J. Abdul Kalam was born on 15 October 1931 in Rameswaram, Tamil Nadu, in a simple and humble family. Despite facing many difficulties in his childhood, he worked very hard and remained dedicated to his studies. He was deeply interested in science and technology from an early age. After completing his education, he joined India’s space and defense programs and made significant contributions to the development of missiles and space research. Because of his remarkable work in missile technology, he became famous as the “Missile Man of India.”

Dr. Kalam played an important role in strengthening India’s defense system. He also contributed greatly to India’s nuclear programs. In 2002, he became the 11th President of India and served the country with honesty, wisdom, and dedication. He was known as the “People’s President” because he connected closely with students and common people. He believed that young people are the future of the nation and always encouraged students to dream big and work hard to achieve success.

Dr. Kalam was not only a scientist and President but also a great teacher, writer, and motivator. He wrote many inspiring books, including Wings of Fire, which motivates millions of people. One of his famous quotes is, “Dream is not that which you see while sleeping; it is something that does not let you sleep.” His life teaches us the importance of hard work, discipline, honesty, and determination. Dr. A.P.J. Abdul Kalam passed away on 27 July 2015 while giving a lecture to students, showing his lifelong dedication to education. He will always remain an inspiration for all of us.

Thank you.
'''
print(paragraph)
# Out:
#    Good morning to everyone present here. Today, I am going to speak about Dr. A.P.J. Abdul Kalam, one of the most respected personalities in India. Dr. A.P.J. Abdul Kalam was born on 15 October 1931 in Rameswaram, Tamil Nadu, in a simple and humble family. Despite facing many difficulties in his childhood, he worked very hard and remained dedicated to his studies. He was deeply interested in science and technology from an early age. After completing his education, he joined India’s space and defense programs and made significant contributions to the development of missiles and space research. Because of his remarkable work in missile technology, he became famous as the “Missile Man of India.”
#
# ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
stop_word = stop_words = stopwords.words('english')

# %%
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.stem import WordNetLemmatizer
stemming = WordNetLemmatizer()
sentences=nltk.sent_tokenize(paragraph)
print(sentences)
# Out:
# ['\n   Good morning to everyone present here.', 'Today, I am going to speak about Dr. A.P.J.', 'Abdul Kalam, one of the most respected personalities in India.', 'Dr. A.P.J.', 'Abdul Kalam was born on 15 October 1931 in Rameswaram, Tamil Nadu, in a simple and humble family.', 'Despite facing many difficulties in his childhood, he worked very hard and remained dedicated to his studies.', 'He was deeply interested in science and technology from an early age.', 'After completing his education, he joined India’s space and defense programs and made significant contributions to the development of missiles and space research.', 'Because of his remarkable work in missile technology, he became famous as the “Missile Man of India.”\n\nDr. Kalam played an important role in strengthening India’s defense system.', 'He also contributed greatly to India’s nuclear programs.', 'In 2002, he became the 11th President of India and served the country with honesty, wisdom, and dedication.', 'He was known a
# ...

# %%
for i in range(len(sentences)):
    words = word_tokenize(sentences[i])
    print(words)
    word = [stemming.lemmatize(w,pos='v') for w in words if w not in stop_words]
    sentences[i] = " ".join(word)
# Out:
# ['Good', 'morning', 'everyone', 'present', '.']
# ['Today', ',', 'I', 'go', 'speak', 'Dr.', 'A.P.J', '.']
# ['Abdul', 'Kalam', ',', 'one', 'respect', 'personalities', 'India', '.']
# ['Dr.', 'A.P.J', '.']
# ['Abdul', 'Kalam', 'bear', '15', 'October', '1931', 'Rameswaram', ',', 'Tamil', 'Nadu', ',', 'simple', 'humble', 'family', '.']
# ['Despite', 'face', 'many', 'difficulties', 'childhood', ',', 'work', 'hard', 'remain', 'dedicate', 'study', '.']
# ['He', 'deeply', 'interest', 'science', 'technology', 'early', 'age', '.']
# ['After', 'complete', 'education', ',', 'join', 'India', '’', 'space', 'defense', 'program', 'make', 'significant', 'contributions', 'development', 'missiles', 'space', 'research', '.']
# ['Because', 'remarkable', 'work', 'missile', 'technology', ',', 'become', 'famous', '“', 'Missile', 'Man', 'India', '.', '”', 'Dr.', 'Kalam', 'play', 'important', 'role', 'strengthen', 'India', '’', 'defense', 'system', '.']
# ...

# %%
for i in range(len(sentences)):
    sentences[i] = "".join(sentences[i])
sentences
# Out:
# ['Good morning everyone present .',
#  'Today , I go speak Dr. A.P.J .',
#  'Abdul Kalam , one respect personalities India .',
#  'Dr. A.P.J .',
#  'Abdul Kalam bear 15 October 1931 Rameswaram , Tamil Nadu , simple humble family .',
#  'Despite face many difficulties childhood , work hard remain dedicate study .',
#  'He deeply interest science technology early age .',
#  'After complete education , join India ’ space defense program make significant contributions development missiles space research .',
#  'Because remarkable work missile technology , become famous “ Missile Man India . ” Dr. Kalam play important role strengthen India ’ defense system .',
#  'He also contribute greatly India ’ nuclear program .',
#  'In 2002 , become 11th President India serve country honesty , wisdom , dedication .',
#  'He know “ People ’ President ” connect closely students common people .',
# ...

# %%
print(paragraph)
print("="*32)
print(sentences)
# Out:
#    Good morning to everyone present here. Today, I am going to speak about Dr. A.P.J. Abdul Kalam, one of the most respected personalities in India. Dr. A.P.J. Abdul Kalam was born on 15 October 1931 in Rameswaram, Tamil Nadu, in a simple and humble family. Despite facing many difficulties in his childhood, he worked very hard and remained dedicated to his studies. He was deeply interested in science and technology from an early age. After completing his education, he joined India’s space and defense programs and made significant contributions to the development of missiles and space research. Because of his remarkable work in missile technology, he became famous as the “Missile Man of India.”
#
# ...
