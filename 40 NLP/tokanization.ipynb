# %%
crops = '''
    Posted by Nikhil Raghavendra, modified by community. See post 'Timeline' for change history
    Retrieved 2026-05-23, License - CC BY-SA 4.0

    This thing seemed to overpower and astonish the little dark-brown dog, and wounded him to the heart. He sank down in despair at the child's feet. When the blow was repeated, together with an admonition in childish sentences, he turned over upon his back, and held his paws in a peculiar manner. At the same time with his ears and his eyes he offered a small prayer to the child.

'''
print(crops)
# Out:
#     Posted by Nikhil Raghavendra, modified by community. See post 'Timeline' for change history
#     Retrieved 2026-05-23, License - CC BY-SA 4.0
#
#     This thing seemed to overpower and astonish the little dark-brown dog, and wounded him to the heart. He sank down in despair at the child's feet. When the blow was repeated, together with an admonition in childish sentences, he turned over upon his back, and held his paws in a peculiar manner. At the same time with his ears and his eyes he offered a small prayer to the child.

# %%
from nltk.tokenize import sent_tokenize,word_tokenize,wordpunct_tokenize
documents = sent_tokenize(crops,language='english')
print(sent_tokenize(crops))
# Out:
# ['\n    Posted by Nikhil Raghavendra, modified by community.', "See post 'Timeline' for change history\n    Retrieved 2026-05-23, License - CC BY-SA 4.0\n\n    This thing seemed to overpower and astonish the little dark-brown dog, and wounded him to the heart.", "He sank down in despair at the child's feet.", 'When the blow was repeated, together with an admonition in childish sentences, he turned over upon his back, and held his paws in a peculiar manner.', 'At the same time with his ears and his eyes he offered a small prayer to the child.']

# %%
world = word_tokenize(crops)
print(world)
# Out:
# ['Posted', 'by', 'Nikhil', 'Raghavendra', ',', 'modified', 'by', 'community', '.', 'See', 'post', "'Timeline", "'", 'for', 'change', 'history', 'Retrieved', '2026-05-23', ',', 'License', '-', 'CC', 'BY-SA', '4.0', 'This', 'thing', 'seemed', 'to', 'overpower', 'and', 'astonish', 'the', 'little', 'dark-brown', 'dog', ',', 'and', 'wounded', 'him', 'to', 'the', 'heart', '.', 'He', 'sank', 'down', 'in', 'despair', 'at', 'the', 'child', "'s", 'feet', '.', 'When', 'the', 'blow', 'was', 'repeated', ',', 'together', 'with', 'an', 'admonition', 'in', 'childish', 'sentences', ',', 'he', 'turned', 'over', 'upon', 'his', 'back', ',', 'and', 'held', 'his', 'paws', 'in', 'a', 'peculiar', 'manner', '.', 'At', 'the', 'same', 'time', 'with', 'his', 'ears', 'and', 'his', 'eyes', 'he', 'offered', 'a', 'small', 'prayer', 'to', 'the', 'child', '.']

# %%
wordpunct_tokenize(crops)
# Out:
# ['Posted',
#  'by',
#  'Nikhil',
#  'Raghavendra',
#  ',',
#  'modified',
#  'by',
#  'community',
#  '.',
#  'See',
#  'post',
#  "'",
#  'Timeline',
#  "'",
#  'for',
#  'change',
#  'history',
#  'Retrieved',
#  '2026',
#  '-',
#  '05',
#  '-',
#  '23',
#  ',',
#  'License',
#  '-',
#  'CC',
#  'BY',
#  '-',
#  'SA',
#  '4',
#  '.',
#  '0',
#  'This',
#  'thing',
#  'seemed',
#  'to',
#  'overpower',
#  'and',
#  'astonish',
#  'the',
#  'little',
#  'dark',
#  '-',
#  'brown',
#  'dog',
#  ',',
#  'and',
#  'wounded',
#  'him',
#  'to',
#  'the',
#  'heart',
#  '.',
#  'He',
#  'sank',
#  'down',
#  'in',
#  'despair',
#  'at',
#  'the',
#  'child',
#  "'",
#  's',
#  'feet',
#  '.',
#  'When',
#  'the',
#  'blow',
#  'was',
#  'repeated',
#  ',',
#  'together',
#  'with',
#  'an',
#  'admonition',
#  'in',
#  'childish',
#  'sentences',
#  ',',
#  'he',
#  'turned',
#  'over',
#  'upon',
#  'his',
#  'back',
#  ',',
#  'and',
#  'held',
#  'his',
#  'paws',
#  'in',
#  'a',
# ...

# %%
from nltk.tokenize import TreebankWordDetokenizer
tokenizer = TreebankWordDetokenizer()
tokenizer.tokenize(crops)
# Out:
# "P o s t e d   b y   N i k h i l   R a g h a v e n d r a,   m o d i f i e d   b y   c o m m u n i t y .   S e e   p o s t  ' T i m e l i n e'   f o r   c h a n g e   h i s t o r y \n         R e t r i e v e d   2 0 2 6 - 0 5 - 2 3,   L i c e n s e   -   C C   B Y - S A   4 . 0 \n \n         T h i s   t h i n g   s e e m e d   t o   o v e r p o w e r   a n d   a s t o n i s h   t h e   l i t t l e   d a r k - b r o w n   d o g,   a n d   w o u n d e d   h i m   t o   t h e   h e a r t .   H e   s a n k   d o w n   i n   d e s p a i r   a t   t h e   c h i l d' s   f e e t .   W h e n   t h e   b l o w   w a s   r e p e a t e d,   t o g e t h e r   w i t h   a n   a d m o n i t i o n   i n   c h i l d i s h   s e n t e n c e s,   h e   t u r n e d   o v e r   u p o n   h i s   b a c k,   a n d   h e l d   h i s   p a w s   i n   a   p e c u l i a r   m a n n e r .   A t   t h e   s a m e   t i m e   w i t h   h i s   e a r s   a n d   h i s   e y e s   h e   o f f e r e d   a   s m a l
# ...
