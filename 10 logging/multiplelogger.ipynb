# %% [markdown]
# Multiple Logger in Python
#
# Python me multiple loggers ka matlab hai alag-alag parts/modules ke liye alag logger banana.

# %%
import logging

logging.basicConfig(level=logging.INFO,format='%(asctime)s - %(levelname)s - %(message)s',force=True)

logger1 = logging.getLogger('logger1')
logger1.setLevel(logging.DEBUG)

logger2 = logging.getLogger('logger2')
logger2.setLevel(logging.WARNING)

# %%
logger1.debug('This is a debug message from logger1')
logger1.info('This is an info message from logger1')
logger2.warning('This is a warning message from logger2')
# Out:
# 2026-05-21 10:17:26,514 - DEBUG - This is a debug message from logger1
# 2026-05-21 10:17:26,514 - INFO - This is an info message from logger1
# 2026-05-21 10:17:26,515 - WARNING - This is a warning message from logger2
